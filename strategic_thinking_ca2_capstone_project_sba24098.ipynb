# %% [markdown]
# # Student Details

# %% [markdown]
# ***
#
# **Name:** Hoai Nhan Nguyen <br>
# **Student Number:** sba24098 <br>
# **Course:** Higher Diploma in Science in Artificial Intelligence Applications
#
# ***

# %% [markdown]
# # Assessment Outline

# %% [markdown]
# **Assessment Task:**<br>
# This assessment aims to evaluate your ability to apply project management methodology to develop and execute a capstone project. You will select a dataset, conduct exploratory data analysis, pre-process the data, implement at least one machine learning algorithm, and present your findings effectively through a comprehensive report. The capstone project will be based on a dataset of your choice from any domain, such as finance, marketing, or any other.

# %% [markdown]
# You will submit a comprehensive report detailing the following

# %% [markdown]
# - Strategic overview of the business problem Project plan
# - Business understanding
# - Data understanding
# - Data preparation
# - Machine learning implementation Findings
# - Conclusions
# - Any future recommendations

# %% [markdown]
# The report should be presented in a clear and concise manner, and it should demonstrate your ability to use a project management methodology. The project management methodology should enable you to prioritise tasks and monitor the progress of the capstone project. Additionally, the report should provide a background to the business problem and its importance from a strategic viewpoint, an overview of the project's timeline, milestones achieved, and any challenges faced during the implementation phase. It should highlight the key insights gained from analysing the data and present any significant trends or patterns observed. Moreover, the report should address any limitations or constraints encountered during the project and propose potential solutions for future improvements.

# %% [markdown]
# This is a two-semester module, and the capstone project will continue into semester two. Students are advised to review and adhere to the submission requirements documented after the assessment task.
#
# ***

# %% [markdown]
# # Exploratory Data Analysis  - Data Understanding

# %% [markdown]
# **1. Importing libraries**

# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns                
import matplotlib.pyplot as plt

# %% [markdown]
# **2. Loading Dataset**

# %%
# Reading the Customer Support Emails - Ticket System - Helpdesk from https://www.kaggle.com/datasets/tobiasbueck/multilingual-customer-support-tickets/data
df = pd.read_csv('data/helpdesk_customer_tickets.csv')

# %% [markdown]
# **3. Inpecting Dataframe Structure**

# %%
# Inpecting the shape of the dataframe.
df.shape
# Out:
# (600, 18)

# %%
# Inpecting the head of the dataframe
df.head(10)
# Out:
#      id                                            subject  \
# 0    36  Anfrage zu den Spezifikationen und Anpassungso...
# 1    39               Déconnexions fréquentes et plantages
# 2   243                        Problema de sonido Dell XPS
# 3   381  Assistance requise pour la configuration du ta...
# 4   663  Urgente: Assistência Imediata Necessária para ...
# 5   673  Problema com o Trackpad do Dell XPS 13 9310 qu...
# 6   717                                                NaN
# 7   900                Frequent Disconnections and Crashes
# 8   929               Não é possível processar o pagamento
# 9  1032  Urgent: Immediate Assistance Required for Serv...
#
#                                                 body  \
# 0  Sehr geehrtes Support-Team des Tech Online Sto...
# 1  Le client signale des déconnexions fréquentes ...
# 2  Problema con el sonido, manejando como devoluc...
# 3  Cher support client,\n\nNotre client, <name>, ...
# 4  Caro Suporte ao Cliente da Firma de Consultori...
# 5  Caro Suporte ao Cliente da Tech Online Store,\...
# 6  Dear Tech Online Store Customer Support,\n\nI ...
# 7  Customer reports frequent disconnections and c...
# 8  Mensagem de erro da transação para o Adobe Pho...
# 9  Dear IT Services Customer Support, \n\nOur ser...
#
#                                               answer      type  \
# 0  Sehr geehrter <name>,\n\nvielen Dank für Ihr I...   Request
# 1  Nous allons enquêter sur le problème avec Zoom...  Incident
# 2  Gracias por su correo electrónico. Procesaremo...   Problem
# 3  Cher <name>,\n\nMerci de nous avoir contactés....   Request
# 4  Caro Cliente,\n\nRecebemos sua solicitação urg...  Incident
# 5  Caro <name>,\n\nObrigado por entrar em contato...   Request
# 6  Dear <name>,\n\nThank you for contacting Tech ...   Problem
# 7  We'll investigate the issue with Zoom 5.11.0. ...  Incident
# 8  Estamos trabalhando para resolver o problema. ...   Problem
# 9  Dear <name>,\n\nThank you for contacting IT Se...   Problem
#
#                    queue priority language                 business_type  \
# 0       Customer Service   medium       de             Tech Online Store
# 1        Product Support     high       fr  Software Development Company
# 2  Returns and Exchanges   medium       es             Tech Online Store
# 3        Product Support   medium       fr  Software Development Company
# 4        Human Resources   medium       pt            IT Consulting Firm
# 5        Product Support   medium       pt             Tech Online Store
# 6  Returns and Exchanges      low       en             Tech Online Store
# 7        Product Support     high       en  Software Development Company
# 8   Billing and Payments      low       pt             Tech Online Store
# 9      Technical Support     high       en                   IT Services
#
#                    tag_1               tag_2                  tag_3  \
# 0        Product Support       Sales Inquiry     Technical Guidance
# 1      Technical Support        Software Bug     Service Disruption
# 2  Returns and Exchanges     Product Support       Customer Service
# 3      Technical Support     Product Support        General Inquiry
# 4           Urgent Issue       Payroll Issue      Technical Support
# 5      Technical Support     Product Support       Hardware Failure
# 6      Technical Support     Product Support  Returns and Exchanges
# 7      Technical Support  Service Disruption          Network Issue
# 8     Payment Processing       Billing Issue           Software Bug
# 9      Technical Support          IT Support           Urgent Issue
#
#                 tag_4               tag_5               tag_6  \
# 0     General Inquiry                 NaN                 NaN
# 1        System Crash  Problem Resolution  Performance Tuning
# 2      Refund Request                 NaN                 NaN
# 3  Problem Resolution    Training Request                 NaN
# 4  Service Disruption  Problem Resolution  Account Assistance
# 5  Problem Resolution    Customer Service  Performance Tuning
# 6       Network Issue    Hardware Failure  Problem Resolution
# 7        Software Bug  Problem Resolution        Urgent Issue
# 8        Urgent Issue                 NaN                 NaN
# 9  Service Disruption        System Crash  Problem Resolution
#
#              tag_7 tag_8  tag_9
# 0              NaN   NaN    NaN
# 1              NaN   NaN    NaN
# 2              NaN   NaN    NaN
# 3              NaN   NaN    NaN
# 4              NaN   NaN    NaN
# 5              NaN   NaN    NaN
# 6              NaN   NaN    NaN
# 7              NaN   NaN    NaN
# 8              NaN   NaN    NaN
# 9  Incident Report   NaN    NaN

# %%
# Inpecting the tail of the dataframe
df.tail(10)
# Out:
#         id                                            subject  \
# 590  97913  Hilfe benötigt bei der Installation von Window...
# 591  98399  Solicitud de Optimización del Rendimiento para...
# 592  98592                         Syntaxhervorhebung Problem
# 593  98678      Issue with Dell XPS 13 9310 Screen Flickering
# 594  99337  Échange demandé pour un ordinateur portable dé...
# 595  99421       Urgente: Problema de Conectividad del Router
# 596  99513  Necesito ayuda con el despliegue de un nuevo m...
# 597  99541                           Necesito soporte urgente
# 598  99603                       Problema de Erro de Servidor
# 599  99709   Wiederholtes Bildschirmflimmern Problem gemeldet
#
#                                                   body  \
# 590  Hallo Tech Online Store Support Team, ich habe...
# 591  Estimado Soporte al Cliente,<br><br>Necesitamo...
# 592  Liebes Support-Team, ich habe ein Problem mit ...
# 593  Dear Tech Online Store Customer Support, I am ...
# 594  Cher support client,\n\nJ'espère que ce messag...
# 595  Estimado Soporte de Servicios de TI,\n\nEstamo...
# 596  Estimado equipo de soporte de servicios de TI,...
# 597  Estimado soporte al cliente, La pantalla tácti...
# 598  Caro Suporte ao Cliente,\n\nNosso Serviço de C...
# 599  Sehr geehrter Kundenservice, ich schreibe, um ...
#
#                                                 answer      type  \
# 590  Hallo <name>,\n\nVielen Dank, dass Sie uns kon...   Request
# 591  Estimado <name>,<br><br>Gracias por ponerte en...   Request
# 592  Lieber <name>,\n\nvielen Dank, dass Sie sich g...   Problem
# 593  Dear <name>,\n\nThank you for reaching out. Pl...  Incident
# 594  Cher <name>,\n\nMerci de nous avoir contactés....   Request
# 595  Estimado <name>,\n\nGracias por ponerte en con...   Problem
# 596  Estimado <name>,\n\nGracias por ponerte en con...   Request
# 597  Estimado <name>,\n\nGracias por ponerte en con...   Problem
# 598  Caro <name>,\n\nObrigado por entrar em contato...  Incident
# 599  Sehr geehrter <name>,\n\nvielen Dank, dass Sie...  Incident
#
#                                queue priority language  \
# 590                  Product Support      low       de
# 591                Technical Support      low       es
# 592                  General Inquiry      low       de
# 593                Technical Support   medium       en
# 594            Returns and Exchanges     high       fr
# 595                       IT Support     high       es
# 596                Technical Support   medium       es
# 597                Technical Support     high       es
# 598  Service Outages and Maintenance     high       pt
# 599                  Product Support   medium       de
#
#                     business_type                  tag_1               tag_2  \
# 590             Tech Online Store      Technical Support        Software Bug
# 591                   IT Services             IT Support  Performance Tuning
# 592  Software Development Company      Technical Support        Software Bug
# 593             Tech Online Store      Technical Support     Product Support
# 594             Tech Online Store  Returns and Exchanges     Product Support
# 595                   IT Services      Technical Support        Urgent Issue
# 596                   IT Services      Technical Support          IT Support
# 597             Tech Online Store      Technical Support        Urgent Issue
# 598                   IT Services      Technical Support          IT Support
# 599             Tech Online Store      Technical Support     Product Support
#
#                   tag_3               tag_4               tag_5  \
# 590  Problem Resolution      Windows Update          IT Support
# 591  Technical Guidance        Urgent Issue  Problem Resolution
# 592  Problem Resolution     Product Support                 NaN
# 593    Hardware Failure  Problem Resolution    Service Recovery
# 594    Customer Service  Problem Resolution   Technical Support
# 595       Network Issue  Problem Resolution  Service Disruption
# 596     Product Support  System Maintenance  Technical Guidance
# 597    Hardware Failure  Problem Resolution     Product Support
# 598  Service Disruption        System Crash  Problem Resolution
# 599    Hardware Failure  Problem Resolution    Service Recovery
#
#                      tag_6 tag_7 tag_8  tag_9
# 590                    NaN   NaN   NaN    NaN
# 591                    NaN   NaN   NaN    NaN
# 592                    NaN   NaN   NaN    NaN
# 593                    NaN   NaN   NaN    NaN
# 594                    NaN   NaN   NaN    NaN
# 595             IT Support   NaN   NaN    NaN
# 596                    NaN   NaN   NaN    NaN
# 597     System Maintenance   NaN   NaN    NaN
# 598                    NaN   NaN   NaN    NaN
# 599  Returns and Exchanges   NaN   NaN    NaN

# %%
# Dropping the id column in the dataframe as it won't be needed for the EDA.
df = df.drop(columns=['id'])

# %%
# Inpecting columns in the dataframe 
df.columns
# Out:
# Index(['subject', 'body', 'answer', 'type', 'queue', 'priority', 'language',
#        'business_type', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6',
#        'tag_7', 'tag_8', 'tag_9'],
#       dtype='object')

# %%
# Inpecting datatype in the dataframe 
df.dtypes
# Out:
# subject           object
# body              object
# answer            object
# type              object
# queue             object
# priority          object
# language          object
# business_type     object
# tag_1             object
# tag_2             object
# tag_3             object
# tag_4             object
# tag_5             object
# tag_6             object
# tag_7             object
# tag_8             object
# tag_9            float64
# dtype: object

# %%
# Inpecting unique values in the dataframe 
df.nunique()
# Out:
# subject          599
# body             600
# answer           600
# type               4
# queue             10
# priority           3
# language           5
# business_type      4
# tag_1             20
# tag_2             30
# tag_3             40
# tag_4             40
# tag_5             43
# tag_6             28
# tag_7             20
# tag_8              8
# tag_9              0
# dtype: int64

# %%
# Inpecting missing values in the dataframe 
df.isna().sum()
# Out:
# subject            1
# body               0
# answer             0
# type               0
# queue              0
# priority           0
# language           0
# business_type      0
# tag_1              0
# tag_2              0
# tag_3              0
# tag_4              0
# tag_5            168
# tag_6            427
# tag_7            544
# tag_8            591
# tag_9            600
# dtype: int64

# %%
# Dropping the columns in the dataframe with missing values 
df = df.drop(columns=['tag_5','tag_6', 'tag_7', 'tag_8', 'tag_9'])

# %%
# Inspecting if there is any duplicate row.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **4. Summarizing and inspecting Categorical Features**

# %%
# Checking frequency distribution of the 'type' feature column 
df['type'].value_counts()
# Out:
# type
# Incident    253
# Request     148
# Problem     145
# Change       54
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'queue' feature column 
df['queue'].value_counts()
# Out:
# queue
# Technical Support                  210
# Product Support                     93
# Customer Service                    85
# IT Support                          77
# Billing and Payments                46
# Returns and Exchanges               41
# Human Resources                     15
# Service Outages and Maintenance     15
# Sales and Pre-Sales                 13
# General Inquiry                      5
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'priority' feature column 
df['priority'].value_counts()
# Out:
# priority
# high      266
# medium    205
# low       129
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'language' feature column 
df['language'].value_counts()
# Out:
# language
# en    163
# de    152
# es    133
# pt     81
# fr     71
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'business_type' feature column 
df['business_type'].value_counts()
# Out:
# business_type
# Tech Online Store               288
# IT Services                     196
# Software Development Company     76
# IT Consulting Firm               40
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'tag_1' feature column 
df['tag_1'].value_counts()
# Out:
# tag_1
# Technical Support        377
# Billing Issue             33
# Product Support           32
# Returns and Exchanges     31
# IT Support                30
# Urgent Issue              29
# Service Outage            12
# Customer Service          10
# Hardware Failure           9
# Software Bug               8
# Warranty Claim             7
# Login Issue                4
# Payment Processing         4
# Service Disruption         3
# Network Issue              3
# System Crash               2
# Sales Inquiry              2
# Performance Tuning         2
# Account Assistance         1
# Data Breach                1
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'tag_2' feature column 
df['tag_2'].value_counts()
# Out:
# tag_2
# Product Support          204
# Software Bug              72
# Urgent Issue              61
# Technical Support         60
# IT Support                53
# Hardware Failure          38
# Customer Service          28
# Returns and Exchanges     10
# Network Issue              9
# Billing Issue              7
# Performance Tuning         6
# Technical Guidance         6
# Payment Processing         6
# Product Replacement        6
# Service Disruption         5
# Problem Resolution         4
# Service Outage             3
# Payroll Issue              3
# Order Issue                3
# Account Assistance         2
# Refund Request             2
# Backup Restore             2
# Sales Inquiry              2
# Critical Failure           2
# Database Corruption        1
# Database Issues            1
# Login Issue                1
# Feature Request            1
# VPN Issue                  1
# General Inquiry            1
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'tag_3' feature column 
df['tag_3'].value_counts()
# Out:
# tag_3
# Hardware Failure         100
# Problem Resolution        98
# Technical Support         57
# Urgent Issue              57
# Software Bug              51
# Customer Service          25
# Product Support           25
# Service Disruption        22
# IT Support                22
# Network Issue             21
# System Maintenance        14
# Account Assistance        14
# Performance Tuning        13
# General Inquiry           10
# Feature Request            9
# Technical Guidance         8
# Returns and Exchanges      7
# Refund Request             6
# Order Issue                5
# Payment Processing         5
# Documentation Request      5
# System Crash               4
# Database Support           2
# Service Recovery           2
# Service Notification       2
# Critical Failure           2
# Service Outage             1
# Troubleshooting            1
# Firmware Update            1
# Audio Issue                1
# Video Conferencing         1
# Billing Issue              1
# Data Recovery              1
# Sales Inquiry              1
# Wireless Printing          1
# Planned Change             1
# Printer Issue              1
# Security Update            1
# System Disruption          1
# Backup Restore             1
# Name: count, dtype: int64

# %%
# Checking frequency distribution of the 'tag_4' feature column 
df['tag_4'].value_counts()
# Out:
# tag_4
# Problem Resolution       241
# Urgent Issue              41
# Software Bug              40
# Product Support           23
# Hardware Failure          23
# Technical Guidance        21
# Customer Service          20
# General Inquiry           17
# Technical Support         17
# Performance Tuning        15
# Network Issue             14
# Service Disruption        14
# Order Issue               13
# Account Assistance        12
# System Crash              12
# IT Support                10
# System Maintenance         9
# Service Recovery           8
# Refund Request             7
# Incident Report            5
# Payment Processing         4
# Sales Inquiry              3
# Wi-Fi Issue                3
# Returns and Exchanges      3
# Critical Failure           3
# Service Notification       3
# Routine Request            2
# Database Issue             2
# Product Replacement        2
# Billing Issue              2
# Windows Update             2
# Shipping Inquiry           1
# Documentation Request      1
# Cloud Services             1
# Database Management        1
# Security Update            1
# Audio Issues               1
# Audio Issue                1
# Video Conference           1
# User Assistance            1
# Name: count, dtype: int64

# %%
# Combining multiple tag columns into one string and sort the tags alphabetically
df['tags'] = df[['tag_1', 'tag_2', 'tag_3', 'tag_4']].apply(lambda row: ', '.join(sorted(row)), axis=1)

# Dropping the tag columns after combining them
df = df.drop(columns=['tag_1','tag_2', 'tag_3', 'tag_4'])

# %%
# Describing a statistical summary of the dataframe 
df.describe()
# Out:
#                                                   subject  \
# count                                                 599
# unique                                                599
# top     Anfrage zu den Spezifikationen und Anpassungso...
# freq                                                    1
#
#                                                      body  \
# count                                                 600
# unique                                                600
# top     Sehr geehrtes Support-Team des Tech Online Sto...
# freq                                                    1
#
#                                                    answer      type  \
# count                                                 600       600
# unique                                                600         4
# top     Sehr geehrter <name>,\n\nvielen Dank für Ihr I...  Incident
# freq                                                    1       253
#
#                     queue priority language      business_type  \
# count                 600      600      600                600
# unique                 10        3        5                  4
# top     Technical Support     high       en  Tech Online Store
# freq                  210      266      163                288
#
#                                                      tags
# count                                                 600
# unique                                                219
# top     Hardware Failure, Problem Resolution, Product ...
# freq                                                   57

# %% [markdown]
# **5. Dataframe Visualization**

# %% [markdown]
# Frequency Distribution of Ticket Types

# %%
# Defining the plot figure size
plt.figure(figsize=(10, 6))

# Getting the count of each ticket type
sns.countplot(data=df, y="type", hue="type", order=df["type"].value_counts().index, palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Frequency Distribution of Ticket Types')
plt.xlabel('Count')
plt.ylabel('Type')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Frequency Distribution of Ticket Business Type

# %%
# Defining the plot figure size
plt.figure(figsize=(10, 6))

# Getting the count of each ticket business type
sns.countplot(data=df, y="business_type", hue="business_type", order=df["business_type"].value_counts().index, palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Frequency Distribution of Ticket Business Type')
plt.xlabel('Count')
plt.ylabel('Business Type')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Frequency Distribution of Ticket Priority

# %%
# Defining the plot figure size
plt.figure(figsize=(10, 6))

# Getting the count of each ticket priority
sns.countplot(data=df, y="priority", hue="priority", order=df["priority"].value_counts().index, palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Frequency Distribution of Ticket Priority')
plt.xlabel('Count')
plt.ylabel('Priority')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Frequency Distribution of tickets based langauges

# %%
# Defining the plot figure size
plt.figure(figsize=(10, 6))

# Getting the count of each ticket language
sns.countplot(data=df, y="language", hue="language", order=df["language"].value_counts().index, palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Frequency Distribution of Ticket Language')
plt.xlabel('Count')
plt.ylabel('Languages')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Tag Frequency Distribution in Tickets

# %%
# Defining the plot figure size
plt.figure(figsize=(10, 15))

# Explode tags into individual rows
df['tags_split'] = df['tags'].str.split(', ')
exploded_df = df.explode('tags_split')

# Getting the count of each tag within tickets
sns.countplot(data=exploded_df, y='tags_split', hue='tags_split', order=exploded_df['tags_split'].value_counts().index, palette='viridis')

# Setting title, xlabel and ylabel
plt.title('Tag Frequency Distribution in Tickets')
plt.xlabel('Count')
plt.ylabel('Tags')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Ticket Type Distribution Across Queues

# %%
# Defining the plot figure size
plt.figure(figsize=(14, 8))

# Getting the count of each ticket queue based on its ticket type 
sns.countplot(data=df, x='queue', hue='type', palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Ticket Type Distribution Across Queues')
plt.xlabel('Queue')
plt.ylabel('Count')

# Setting the text 45 degrees for the queues for readability 
plt.xticks(rotation=45, ha='right')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Priority Distribution Across Queues

# %%
# Defining the plot figure size
plt.figure(figsize=(14, 8))

# Getting the count of each ticket queue based on its priority 
sns.countplot(data=df, x='queue', hue='priority', palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Priority Distribution Across Queues')
plt.xlabel('Queue')
plt.ylabel('Count')

# Setting the text 45 degrees for the queues for readability 
plt.xticks(rotation=45, ha='right')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Ticket Language Distribution Across Queues

# %%
# Defining the plot figure size
plt.figure(figsize=(14, 8))

# Getting the count of each ticket queue based on its language
sns.countplot(data=df, x='queue', hue='language', palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Ticket Type Distribution Across Queues')
plt.xlabel('Queue')
plt.ylabel('Count')

# Setting the text 45 degrees for the queues for readability 
plt.xticks(rotation=45, ha='right')

# Showing the plot based on the data
plt.show()

# %% [markdown]
# Ticket Buiness Type Distribution Across Queues

# %%
# Defining the plot figure size
plt.figure(figsize=(14, 8))

# Getting the count of each ticket queue based on its language
sns.countplot(data=df, x='queue', hue='business_type', palette="viridis")

# Setting title, xlabel and ylabel
plt.title('Ticket Buiness Type Distribution Across Queues')
plt.xlabel('Queue')
plt.ylabel('Count')

# Setting the text 45 degrees for the queues for readability 
plt.xticks(rotation=45, ha='right')

# Showing the plot based on the data
plt.show()
